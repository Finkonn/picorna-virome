# %%
import pandas as pd

# %%
df_zover = pd.read_excel('ZOVER_all_bat_viruses.xlsx', header=1)
df_zover
# Out:
#                                     SampleName                    Host  \
# 0                                         Bat1      Artibeus lituratus
# 1                                         Bat2  Carollia perspicillata
# 2                                         Bat3  Carollia perspicillata
# 3                                         Bat4    Glossophaga soricina
# 4                                         Bat5    Glossophaga soricina
# ...                                        ...                     ...
# 2967                                 Rt22QT161     Rhinolophus thomasi
# 2968                                 Rt22QT178     Rhinolophus thomasi
# 2969                                   Rt22QB8     Rhinolophus thomasi
# 2970                                  Rt22QB78     Rhinolophus thomasi
# 2971  Table saved from ZOVER [Wed Apr 01 2026]                     NaN
#
#            CollectionDate  Country    Province        City SampleDetails  \
# 0     2007-10-05 00:00:00   Brazil   Sao Paulo  Valparaiso        Kidney
# 1     2007-10-19 00:00:00   Brazil   Sao Paulo   Aracatuba         Liver
# 2     2007-10-19 00:00:00   Brazil   Sao Paulo   Aracatuba        Kidney
# 3     2007-10-19 00:00:00   Brazil   Sao Paulo   Aracatuba         Liver
# 4     2007-10-19 00:00:00   Brazil   Sao Paulo   Aracatuba        Kidney
# ...                   ...      ...         ...         ...           ...
# 2967  2022-11-05 00:00:00  Vietnam   Quang Tri          ND         Feces
# 2968  2022-11-05 00:00:00  Vietnam   Quang Tri          ND         Feces
# 2969  2022-11-07 00:00:00  Vietnam  Quang Binh          ND         Feces
# 2970  2022-11-10 00:00:00  Vietnam  Quang Binh          ND         Feces
# 2971                  NaN      NaN         NaN         NaN           NaN
#
#         BioProject     BioSample
# 0      PRJNA557656  SAMN12405593
# 1      PRJNA557656  SAMN12405594
# 2      PRJNA557656  SAMN12405595
# 3      PRJNA557656  SAMN12405596
# 4      PRJNA557656  SAMN12405597
# ...            ...           ...
# 2967  PRJNA1025946  SAMN37730889
# 2968  PRJNA1025946  SAMN37730890
# 2969  PRJNA1025946  SAMN37730872
# 2970  PRJNA1025946  SAMN37730871
# 2971           NaN           NaN
#
# [2972 rows x 9 columns]

# %%
df_our = pd.read_csv('latest_SRA_6569.csv', index_col=False)
df_our
# Out:
# D:\Users\User\AppData\Local\Temp\ipykernel_6148\1657131637.py:1: DtypeWarning: Columns (0: Location_Province, 1: ArrayExpress-SPECIES, 2: common_name, 3: ENA-FIRST-PUBLIC, 4: ENA-LAST-UPDATE, 5: external_id, 6: INSDC_first_public, 7: INSDC_last_update, 8: sample_description, 9: Sample_Barcode, 10: ref_biomaterial, 11: collected_by, 12: Broker_name, 13: env_biome, 14: env_feature, 15: env_material, 16: Biological_Replicate, 17: host_scientific_name, 18: lab_host, 19: specimen_voucher, 20: expected_source, 21: host_body_product, 22: host_tot_mass, 23: manuscript_id, 24: samp_capt_status, 25: samp_collect_device, 26: fasta_file (run), 27: sample_type, 28: sex, 29: BREED, 30: Cultivar, 31: dev_stage, 32: ecotype, 33: sub_species, 34: samp_size, 35: Library_ID, 36: rel_to_oxygen, 37: Detail_ID, 38: replicate, 39: SUBMISSION_TOOL (exp), 40: SUBMISSION_TOOL (run), 41: submission_tool, 42: SUBMISSION_TOOL_VERSION (exp), 43: SUBMISSION_TOOL_VERSION (run), 44: SUBMISSION_TOOL_VERSION, 45: genbank_accession, 46: sequencing_approach, 47: matrix_type, 48: organism_spiked_and_spike_in_level, 49: virus_enrich_app, 50: experimental_factor, 51: sample_ID, 52: specific_host, 53: additional_component_added_to_sample, 54: altitude, 55: BIOME, 56: env_package, 57: feature, 58: Investigation_type, 59: Label, 60: material, 61: sample_comment, 62: spike_in_level_of_influenza_a_virus) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_our = pd.read_csv('latest_SRA_6569.csv', index_col=False)
#               Run Assay Type  AvgSpotLen        Bases       BioSample  \
# 0     SRR27491126   AMPLICON         300   3796245900    SAMN39397543
# 1     SRR27491127   AMPLICON         300   2721147000    SAMN39397542
# 2     SRR27491128   AMPLICON         300   4709894100    SAMN39397541
# 3     SRR27491129   AMPLICON         300   4779211500    SAMN39397540
# 4     SRR27491130   AMPLICON         300   5456230500    SAMN39397539
# ...           ...        ...         ...          ...             ...
# 6564  ERR15951191        WGS         212  10740246317  SAMEA120589881
# 6565  ERR15951193        WGS         280  59183488003  SAMEA120589883
# 6566  ERR15951194        WGS         271  35140445635  SAMEA120589884
# 6567  ERR15951203        WGS         274   6685169405  SAMEA120589893
# 6568  SRR36330079    RNA-Seq         265        20195    SAMN53697127
#
#             Bytes                      Center Name Consent DATASTORE filetype  \
# 0      2388715895     INSTITUT PASTEUR OF SHANGHAI  public   fastq,run.zq,sra
# 1      1707201651     INSTITUT PASTEUR OF SHANGHAI  public   fastq,run.zq,sra
# 2      2950874629     INSTITUT PASTEUR OF SHANGHAI  public   fastq,run.zq,sra
# 3      3015086016     INSTITUT PASTEUR OF SHANGHAI  public   fastq,run.zq,sra
# 4      3394419299     INSTITUT PASTEUR OF SHANGHAI  public   fastq,run.zq,sra
# ...           ...                              ...     ...                ...
# 6564   3365993450     QUADRAM INSTITUTE BIOSCIENCE  public   fastq,run.zq,sra
# 6565  17798921408     QUADRAM INSTITUTE BIOSCIENCE  public   fastq,run.zq,sra
# 6566  10911327171     QUADRAM INSTITUTE BIOSCIENCE  public   fastq,run.zq,sra
# 6567   2044166040     QUADRAM INSTITUTE BIOSCIENCE  public   fastq,run.zq,sra
# 6568        92144  FEDERAL UNIVERSITY OF SAO PAULO  public            bam,sra
#
#      DATASTORE provider  ... additional_component_added_to_sample altitude  \
# 0            gs,ncbi,s3  ...                                  NaN      NaN
# 1            gs,ncbi,s3  ...                                  NaN      NaN
# 2            gs,ncbi,s3  ...                                  NaN      NaN
# 3            gs,ncbi,s3  ...                                  NaN      NaN
# 4            gs,ncbi,s3  ...                                  NaN      NaN
# ...                 ...  ...                                  ...      ...
# 6564         gs,ncbi,s3  ...                                  NaN      NaN
# 6565         gs,ncbi,s3  ...                                  NaN      NaN
# 6566         gs,ncbi,s3  ...                                  NaN      NaN
# 6567         gs,ncbi,s3  ...                                  NaN      NaN
# 6568         gs,ncbi,s3  ...                                  NaN      NaN
#
#      BIOME env_package feature Investigation_type Label material  \
# 0      NaN         NaN     NaN                NaN   NaN      NaN
# 1      NaN         NaN     NaN                NaN   NaN      NaN
# 2      NaN         NaN     NaN                NaN   NaN      NaN
# 3      NaN         NaN     NaN                NaN   NaN      NaN
# 4      NaN         NaN     NaN                NaN   NaN      NaN
# ...    ...         ...     ...                ...   ...      ...
# 6564   NaN         NaN     NaN                NaN   NaN      NaN
# 6565   NaN         NaN     NaN                NaN   NaN      NaN
# 6566   NaN         NaN     NaN                NaN   NaN      NaN
# 6567   NaN         NaN     NaN                NaN   NaN      NaN
# 6568   NaN         NaN     NaN                NaN   NaN      NaN
#
#      sample_comment spike_in_level_of_influenza_a_virus
# 0               NaN                                 NaN
# 1               NaN                                 NaN
# 2               NaN                                 NaN
# 3               NaN                                 NaN
# 4               NaN                                 NaN
# ...             ...                                 ...
# 6564            NaN                                 NaN
# 6565            NaN                                 NaN
# 6566            NaN                                 NaN
# 6567            NaN                                 NaN
# 6568            NaN                                 NaN
#
# [6569 rows x 136 columns]

# %%
import pandas as pd


with open('projects_to_remove.txt', 'r') as f:
    projects_to_remove = [line.strip() for line in f]

df_filtered = df_our[~df_our['BioProject'].isin(projects_to_remove)]

df_filtered.to_csv('filtered_table.csv', index=False)

# %%
df_our = pd.read_csv('filtered_table.csv', index_col=False)
df_our
# Out:
# D:\Users\User\AppData\Local\Temp\ipykernel_6148\2315709968.py:1: DtypeWarning: Columns (0: Location_Province, 1: ArrayExpress-SPECIES, 2: common_name, 3: ENA-FIRST-PUBLIC, 4: ENA-LAST-UPDATE, 5: external_id, 6: INSDC_first_public, 7: INSDC_last_update, 8: sample_description, 9: Sample_Barcode, 10: ref_biomaterial, 11: collected_by, 12: Broker_name, 13: env_biome, 14: env_feature, 15: env_material, 16: Biological_Replicate, 17: host_scientific_name, 18: lab_host, 19: specimen_voucher, 20: expected_source, 21: host_body_product, 22: host_tot_mass, 23: manuscript_id, 24: samp_capt_status, 25: samp_collect_device, 26: fasta_file (run), 27: sample_type, 28: sex, 29: BREED, 30: Cultivar, 31: dev_stage, 32: ecotype, 33: sub_species, 34: samp_size, 35: Library_ID, 36: rel_to_oxygen, 37: replicate, 38: SUBMISSION_TOOL (exp), 39: SUBMISSION_TOOL (run), 40: submission_tool, 41: SUBMISSION_TOOL_VERSION (exp), 42: SUBMISSION_TOOL_VERSION (run), 43: SUBMISSION_TOOL_VERSION, 44: genbank_accession, 45: sequencing_approach, 46: virus_enrich_app, 47: experimental_factor, 48: sample_ID, 49: specific_host, 50: altitude, 51: BIOME, 52: env_package, 53: feature, 54: Investigation_type, 55: Label, 56: material, 57: sample_comment) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_our = pd.read_csv('filtered_table.csv', index_col=False)
#               Run Assay Type  AvgSpotLen        Bases       BioSample  \
# 0     SRR31363909        WGS         286    474453275    SAMN44728217
# 1     SRR31363910        WGS         299    598547547    SAMN44728216
# 2     SRR31363911        WGS         298     57040761    SAMN44727980
# 3     SRR31363912        WGS         274    545825235    SAMN44727979
# 4     SRR31363913        WGS         263   1442370106    SAMN44727972
# ...           ...        ...         ...          ...             ...
# 6463  ERR15951191        WGS         212  10740246317  SAMEA120589881
# 6464  ERR15951193        WGS         280  59183488003  SAMEA120589883
# 6465  ERR15951194        WGS         271  35140445635  SAMEA120589884
# 6466  ERR15951203        WGS         274   6685169405  SAMEA120589893
# 6467  SRR36330079    RNA-Seq         265        20195    SAMN53697127
#
#             Bytes                      Center Name Consent DATASTORE filetype  \
# 0       173166448             REDEEMERS UNIVERSITY  public   fastq,run.zq,sra
# 1       221765048             REDEEMERS UNIVERSITY  public   fastq,run.zq,sra
# 2        34122192             REDEEMERS UNIVERSITY  public   fastq,run.zq,sra
# 3       219057341             REDEEMERS UNIVERSITY  public   fastq,run.zq,sra
# 4       539922913             REDEEMERS UNIVERSITY  public   fastq,run.zq,sra
# ...           ...                              ...     ...                ...
# 6463   3365993450     QUADRAM INSTITUTE BIOSCIENCE  public   fastq,run.zq,sra
# 6464  17798921408     QUADRAM INSTITUTE BIOSCIENCE  public   fastq,run.zq,sra
# 6465  10911327171     QUADRAM INSTITUTE BIOSCIENCE  public   fastq,run.zq,sra
# 6466   2044166040     QUADRAM INSTITUTE BIOSCIENCE  public   fastq,run.zq,sra
# 6467        92144  FEDERAL UNIVERSITY OF SAO PAULO  public            bam,sra
#
#      DATASTORE provider  ... additional_component_added_to_sample altitude  \
# 0            gs,ncbi,s3  ...                                  NaN      NaN
# 1            gs,ncbi,s3  ...                                  NaN      NaN
# 2            gs,ncbi,s3  ...                                  NaN      NaN
# 3            gs,ncbi,s3  ...                                  NaN      NaN
# 4            gs,ncbi,s3  ...                                  NaN      NaN
# ...                 ...  ...                                  ...      ...
# 6463         gs,ncbi,s3  ...                                  NaN      NaN
# 6464         gs,ncbi,s3  ...                                  NaN      NaN
# 6465         gs,ncbi,s3  ...                                  NaN      NaN
# 6466         gs,ncbi,s3  ...                                  NaN      NaN
# 6467         gs,ncbi,s3  ...                                  NaN      NaN
#
#      BIOME env_package feature Investigation_type Label material  \
# 0      NaN         NaN     NaN                NaN   NaN      NaN
# 1      NaN         NaN     NaN                NaN   NaN      NaN
# 2      NaN         NaN     NaN                NaN   NaN      NaN
# 3      NaN         NaN     NaN                NaN   NaN      NaN
# 4      NaN         NaN     NaN                NaN   NaN      NaN
# ...    ...         ...     ...                ...   ...      ...
# 6463   NaN         NaN     NaN                NaN   NaN      NaN
# 6464   NaN         NaN     NaN                NaN   NaN      NaN
# 6465   NaN         NaN     NaN                NaN   NaN      NaN
# 6466   NaN         NaN     NaN                NaN   NaN      NaN
# 6467   NaN         NaN     NaN                NaN   NaN      NaN
#
#      sample_comment spike_in_level_of_influenza_a_virus
# 0               NaN                                 NaN
# 1               NaN                                 NaN
# 2               NaN                                 NaN
# 3               NaN                                 NaN
# 4               NaN                                 NaN
# ...             ...                                 ...
# 6463            NaN                                 NaN
# 6464            NaN                                 NaN
# 6465            NaN                                 NaN
# 6466            NaN                                 NaN
# 6467            NaN                                 NaN
#
# [6468 rows x 136 columns]

# %%
matching_rows = df_our[df_our['BioSample'].isin(df_zover['BioSample'])]
matching_rows
# Out:
#               Run Assay Type  AvgSpotLen       Bases     BioSample  \
# 95    SRR27912327        WGS         298  3085496470  SAMN39879846
# 96    SRR27912328        WGS         298  3272640768  SAMN39879845
# 97    SRR27912329        WGS         276  1351361039  SAMN39879844
# 98    SRR27912330        WGS         298  4386745356  SAMN39879843
# 99    SRR27912331        WGS         298  3616133150  SAMN39879842
# ...           ...        ...         ...         ...           ...
# 5741  SRR28251003    RNA-Seq         298  7397556171  SAMN40258855
# 5742  SRR28251004    RNA-Seq         299  1417736932  SAMN40258854
# 5743  SRR28251005    RNA-Seq         299  1257774019  SAMN40258853
# 5744  SRR28251006    RNA-Seq         298  3507101388  SAMN40258852
# 5745  SRR28251010    RNA-Seq         298  9478727499  SAMN40259160
#
#            Bytes              Center Name Consent DATASTORE filetype  \
# 95    1259025954  UNIVERSITAT DE VALENCIA  public   fastq,run.zq,sra
# 96    1315849459  UNIVERSITAT DE VALENCIA  public   fastq,run.zq,sra
# 97     780573312  UNIVERSITAT DE VALENCIA  public   fastq,run.zq,sra
# 98    1906501423  UNIVERSITAT DE VALENCIA  public   fastq,run.zq,sra
# 99    1576038134  UNIVERSITAT DE VALENCIA  public   fastq,run.zq,sra
# ...          ...                      ...     ...                ...
# 5741  4697649447             BGI RESEARCH  public   fastq,run.zq,sra
# 5742   918749601             BGI RESEARCH  public   fastq,run.zq,sra
# 5743   808112824             BGI RESEARCH  public   fastq,run.zq,sra
# 5744  2187692259             BGI RESEARCH  public   fastq,run.zq,sra
# 5745  5998889224             BGI RESEARCH  public   fastq,run.zq,sra
#
#      DATASTORE provider  ... additional_component_added_to_sample altitude  \
# 95           gs,ncbi,s3  ...                                  NaN      NaN
# 96           gs,ncbi,s3  ...                                  NaN      NaN
# 97           gs,ncbi,s3  ...                                  NaN      NaN
# 98           gs,ncbi,s3  ...                                  NaN      NaN
# 99           gs,ncbi,s3  ...                                  NaN      NaN
# ...                 ...  ...                                  ...      ...
# 5741         gs,ncbi,s3  ...                                  NaN      NaN
# 5742         gs,ncbi,s3  ...                                  NaN      NaN
# 5743         gs,ncbi,s3  ...                                  NaN      NaN
# 5744         gs,ncbi,s3  ...                                  NaN      NaN
# 5745         gs,ncbi,s3  ...                                  NaN      NaN
#
#      BIOME env_package feature Investigation_type Label material  \
# 95     NaN         NaN     NaN                NaN   NaN      NaN
# 96     NaN         NaN     NaN                NaN   NaN      NaN
# 97     NaN         NaN     NaN                NaN   NaN      NaN
# 98     NaN         NaN     NaN                NaN   NaN      NaN
# 99     NaN         NaN     NaN                NaN   NaN      NaN
# ...    ...         ...     ...                ...   ...      ...
# 5741   NaN         NaN     NaN                NaN   NaN      NaN
# 5742   NaN         NaN     NaN                NaN   NaN      NaN
# 5743   NaN         NaN     NaN                NaN   NaN      NaN
# 5744   NaN         NaN     NaN                NaN   NaN      NaN
# 5745   NaN         NaN     NaN                NaN   NaN      NaN
#
#      sample_comment spike_in_level_of_influenza_a_virus
# 95              NaN                                 NaN
# 96              NaN                                 NaN
# 97              NaN                                 NaN
# 98              NaN                                 NaN
# 99              NaN                                 NaN
# ...             ...                                 ...
# 5741            NaN                                 NaN
# 5742            NaN                                 NaN
# 5743            NaN                                 NaN
# 5744            NaN                                 NaN
# 5745            NaN                                 NaN
#
# [1690 rows x 136 columns]

# %%
matching_rows.to_csv('matching.csv')

# %%
not_matching_rows = df_our[~df_our['BioSample'].isin(df_zover['BioSample'])]
not_matching_rows['Collection_Date'].value_counts().to_csv('not_matched_dates.csv')

# %%
not_matching_rows.to_csv('not_matching.csv')

# %%
df_matches = pd.DataFrame()

# %%
df_matches['Matches'] = df_our['BioSample'].isin(df_zover['BioSample'])

# %%
df_matches['Project'] = df_our['BioProject'].isin(df_zover['BioProject'])

# %%
df_matches['Matches'].value_counts()
# Out:
# Matches
# False    4879
# True     1690
# Name: count, dtype: int64

# %%
df_matches['Project'].value_counts()
# Out:
# Project
# False    4839
# True     1730
# Name: count, dtype: int64

# %%
df_matches
# Out:
#       Matches  Project
# 0       False    False
# 1       False    False
# 2       False    False
# 3       False    False
# 4       False    False
# ...       ...      ...
# 6564    False    False
# 6565    False    False
# 6566    False    False
# 6567    False    False
# 6568    False    False
#
# [6569 rows x 2 columns]
